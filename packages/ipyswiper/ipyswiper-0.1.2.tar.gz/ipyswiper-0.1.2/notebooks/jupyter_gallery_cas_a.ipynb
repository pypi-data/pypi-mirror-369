# %%
from ipyswiper import IpySwiper

# %%
import json
j = json.load(open("data/cas_a.json"))

# %%
gallery = IpySwiper(j, base_path="/files/notebooks/")

gallery  # This will display the gallery
# Out:
#         <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/swiper@11/swiper-bundle.min.css" />
#         <script src="https://cdn.jsdelivr.net/npm/swiper@11/swiper-bundle.min.js"></script>
#         <div id="gallery-a2b52e36" class="gallery-container" tabindex="0">
#     <div class="gallery-content">
#         <div class="swiper main-swiper">
#             <div class="swiper-wrapper">
#
#                 <div class="swiper-slide">
#                     <img src="/files/notebooks/data/images_cas_a/cas_a_000.jpg" alt="0.741" loading="lazy">
#                 </div>
#
#                 <div class="swiper-slide">
#                     <img src="/files/notebooks/data/images_cas_a/cas_a_001.jpg" alt="0.759" loading="lazy">
#                 </div>
#
#                 <div class="swiper-slide">
#                     <img src="/files/notebooks/data/images_cas_a/cas_a_002.jpg" alt="0.776" loading="lazy">
#                 </div>
#
#                 <div class="swiper-slide">
# ...
