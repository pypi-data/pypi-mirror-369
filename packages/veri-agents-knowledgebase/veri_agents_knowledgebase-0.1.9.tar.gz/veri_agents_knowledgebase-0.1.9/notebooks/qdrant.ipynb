# %%
from langchain_aws import BedrockEmbeddings
from langchain_qdrant import FastEmbedSparse, QdrantVectorStore, RetrievalMode
from qdrant_client import QdrantClient, models

embedding_model = BedrockEmbeddings(
    model_id="amazon.titan-embed-text-v2:0",
    aws_access_key_id="AKIARDE6USWW667TCMJW",  # pyright: ignore[reportArgumentType]
    aws_secret_access_key="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",  # pyright: ignore[reportArgumentType]
    region_name="us-east-1",
)

qdrant = QdrantClient("http://0.0.0.0:6333")
sparse_embeddings = FastEmbedSparse(model_name="Qdrant/bm25")
vector_store = QdrantVectorStore(
    client=qdrant,
    collection_name="chunks_realtimecrime",
    embedding=embedding_model,  # pyright: ignore[reportArgumentType]
    retrieval_mode=RetrievalMode.HYBRID,
    vector_name="dense",
    sparse_embedding=sparse_embeddings,
    sparse_vector_name="sparse",
)

sub_docs = vector_store.similarity_search_with_score(
    query="texas", k=10
)

sub_docs
# Out:
# [(Document(metadata={'schema_name': 'docling_core.transforms.chunker.DocMeta', 'version': '1.0.0', 'doc_items': [{'self_ref': '#/texts/7472', 'parent': {'$ref': '#/body'}, 'children': [], 'content_layer': 'body', 'label': 'text', 'prov': [{'page_no': 442, 'bbox': {'l': 54.0, 't': 555.548, 'r': 550.8, 'b': 514.116, 'coord_origin': 'BOTTOMLEFT'}, 'charspan': [0, 201]}]}, {'self_ref': '#/texts/7473', 'parent': {'$ref': '#/groups/981'}, 'children': [], 'content_layer': 'body', 'label': 'list_item', 'prov': [{'page_no': 442, 'bbox': {'l': 54.0, 't': 507.548, 'r': 529.2, 'b': 482.116, 'coord_origin': 'BOTTOMLEFT'}, 'charspan': [0, 93]}]}, {'self_ref': '#/texts/7474', 'parent': {'$ref': '#/groups/981'}, 'children': [], 'content_layer': 'body', 'label': 'list_item', 'prov': [{'page_no': 442, 'bbox': {'l': 120.0, 't': 475.548, 'r': 400.8, 'b': 466.116, 'coord_origin': 'BOTTOMLEFT'}, 'charspan': [0, 39]}]}, {'self_ref': '#/texts/7475', 'parent': {'$ref': '#/groups/981'}, 'children': [], 'conte
# ...
